# %% [markdown]
# <a href="https://colab.research.google.com/github/hewp84/CRT420/blob/main/Pandas_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PANDAS: Grouping & Reshaping

# %% [markdown]
# ## Grouping
#
# Grouping is a fundamental operation that allows us to split our data into groups based on specific criteria, and then perform operations on each group separately.

# %% [markdown]
# **Syntax:**
#
# `df.groupby(by=None, axis=0, level=None, as_index=True, sort=True, group_keys=True, squeeze=<no_default>, observed=False, dropna=True)`
#
# **Parameters:**
#
# * by : Mapping, function, str, or iterable to group by. Column name/s or index level/s to group.
# * axis : Axis to group over. 0 for rows and 1 for columns. Default is 0.
# * level : Level of MultiIndex to group.
# * as_index : Group by index if True, else by values. Default is True.
# * sort : Sort groups if True. Default is True.
# * group_keys : Add group keys to index. Default is True.
# * squeeze : Return NumPy value if possible.
# * observed : Use only observed values.
# * dropna : Don't include NaN values. Default is True.
#
# **Returns:**
#
# A groupby object that contains information about the groups.

# %%
# Import necessary libraries
import pandas as pd

# Create a sample DataFrame
data = {
    'Category': ['A', 'B', 'A', 'B', 'A', 'B','C'],
    'Value': [10, 15, 20, 25, 30, 35, 67]
}

df = pd.DataFrame(data)

# Display the DataFrame
df
# Out:
#   Category  Value
# 0        A     10
# 1        B     15
# 2        A     20
# 3        B     25
# 4        A     30
# 5        B     35
# 6        C     67

# %% [markdown]
# To group data in Pandas, we can use the `groupby()` method, which is often followed by an aggregation operation. Let's start by grouping our sample DataFrame `df` by the 'Category' column.

# %%
# Group the DataFrame by 'Category'
grouped = df.groupby(by='Category')

# Display the grouped object
grouped

# %%
# Calculate the mean value for each group
grouped_mean = grouped.mean()

# Display the mean values
grouped_mean
# Out:
#           Value
# Category
# A          20.0
# B          25.0

# %%
#Try alternative mathematical methods such as sum, mean, etc
grouped_example = grouped.max()

grouped_example
# Out:
#           Value
# Category
# A            30
# B            35
# C            67

# %% [markdown]
# #### Aggregation
#
# We can also iterate through the groups and perform custom operations on each group. Let's print the groups and their corresponding data:

# %%
# Iterate through groups and print the group name and data
for name, group in grouped:
    print(f"Group: {name}")
    print(group)
    print()
# Out:
# Group: A
#   Category  Value
# 0        A     10
# 2        A     20
# 4        A     30
#
# Group: B
#   Category  Value
# 1        B     15
# 3        B     25
# 5        B     35

# %% [markdown]
# #### Applying Multiple Aggregations
#
# Pandas allows us to apply multiple aggregation functions at once using the `agg()` method. Let's calculate both the mean and sum for each group.

# %%
# Calculate both mean and sum for each group
grouped_agg = grouped['Value'].agg(['mean', 'sum','max'])

# Display the aggregated results
grouped_agg
# Out:
#           mean  sum  max
# Category
# A         20.0   60   30
# B         25.0   75   35
# C         67.0   67   67

# %% [markdown]
# #### Custom Aggregation Functions
#
# You can define custom aggregation functions to apply to groups. Let's create a custom function to calculate the range for each group.

# %%
# Custom aggregation function to calculate the range
def custom_range(x):
    return x.max()-x.min()

# Apply the custom aggregation function
range_result = grouped['Value'].agg(custom_range)

# Display the range for each group
range_result
# Out:
# Category
# A    20
# B    20
# C     0
# Name: Value, dtype: int64

# %% [markdown]
# #### Real life dataset: ATP Tour 2013-2023

# %%
atp = pd.read_csv('atp_tennis.csv')
atp
# Out:
#                    Tournament        Date        Series    Court Surface  \
# 0      Brisbane International  2012-12-31        ATP250  Outdoor    Hard
# 1      Brisbane International  2012-12-31        ATP250  Outdoor    Hard
# 2      Brisbane International  2012-12-31        ATP250  Outdoor    Hard
# 3      Brisbane International  2012-12-31        ATP250  Outdoor    Hard
# 4      Brisbane International  2013-01-01        ATP250  Outdoor    Hard
# ...                       ...         ...           ...      ...     ...
# 25357              Miami Open  2023-03-30  Masters 1000  Outdoor    Hard
# 25358              Miami Open  2023-03-31  Masters 1000  Outdoor    Hard
# 25359              Miami Open  2023-03-31  Masters 1000  Outdoor    Hard
# 25360              Miami Open  2023-04-01  Masters 1000  Outdoor    Hard
# 25361              Miami Open  2023-04-02  Masters 1000  Outdoor    Hard
#
#                Round  Best of      Player_1      Player_2        Winner  \
# 0          1st Round        3      Mayer F.    Giraldo S.      Mayer F.
# 1          1st Round        3  Benneteau J.   Nieminen J.   Nieminen J.
# 2          1st Round        3  Nishikori K.  Matosevic M.  Nishikori K.
# 3          1st Round        3   Mitchell B.  Baghdatis M.  Baghdatis M.
# 4          1st Round        3    Istomin D.     Klizan M.    Istomin D.
# ...              ...      ...           ...           ...           ...
# 25357  Quarterfinals        3  Cerundolo F.  Khachanov K.  Khachanov K.
# 25358  Quarterfinals        3    Alcaraz C.      Fritz T.    Alcaraz C.
# 25359     Semifinals        3  Khachanov K.   Medvedev D.   Medvedev D.
# 25360     Semifinals        3     Sinner J.    Alcaraz C.     Sinner J.
# 25361      The Final        3     Sinner J.   Medvedev D.   Medvedev D.
#
#        Rank_1  Rank_2  Pts_1  Pts_2  Odd_1  Odd_2          score
# 0          28      57   1215    778   1.36   3.00     6-4 6-4
# 1          35      41   1075    927   2.20   1.61  3-6 6-2 1-6
# 2          19      49   1830    845   1.25   3.75     7-5 6-2
# 3         326      36    137   1070   9.00   1.07     4-6 4-6
# 4          43      30    897   1175   1.90   1.80     6-1 6-2
# ...       ...     ...    ...    ...    ...    ...            ...
# 25357      31      16   1320   2505   3.20   1.36     3-6 2-6
# 25358       1      10   7420   2975   1.22   4.33     6-4 6-2
# 25359      16       5   2505   4330   4.50   1.20  6-7 6-3 3-6
# 25360      11       1   2925   7420   3.00   1.40  6-7 6-4 6-2
# 25361      11       5   2925   4330   1.91   1.91     5-7 3-6
#
# [25362 rows x 17 columns]

# %%
#Filtering only for Hard surface data
hard = atp[atp['Surface'] == 'Hard']
hard
# Out:
#                    Tournament        Date        Series    Court Surface  \
# 0      Brisbane International  2012-12-31        ATP250  Outdoor    Hard
# 1      Brisbane International  2012-12-31        ATP250  Outdoor    Hard
# 2      Brisbane International  2012-12-31        ATP250  Outdoor    Hard
# 3      Brisbane International  2012-12-31        ATP250  Outdoor    Hard
# 4      Brisbane International  2013-01-01        ATP250  Outdoor    Hard
# ...                       ...         ...           ...      ...     ...
# 25357              Miami Open  2023-03-30  Masters 1000  Outdoor    Hard
# 25358              Miami Open  2023-03-31  Masters 1000  Outdoor    Hard
# 25359              Miami Open  2023-03-31  Masters 1000  Outdoor    Hard
# 25360              Miami Open  2023-04-01  Masters 1000  Outdoor    Hard
# 25361              Miami Open  2023-04-02  Masters 1000  Outdoor    Hard
#
#                Round  Best of      Player_1      Player_2        Winner  \
# 0          1st Round        3      Mayer F.    Giraldo S.      Mayer F.
# 1          1st Round        3  Benneteau J.   Nieminen J.   Nieminen J.
# 2          1st Round        3  Nishikori K.  Matosevic M.  Nishikori K.
# 3          1st Round        3   Mitchell B.  Baghdatis M.  Baghdatis M.
# 4          1st Round        3    Istomin D.     Klizan M.    Istomin D.
# ...              ...      ...           ...           ...           ...
# 25357  Quarterfinals        3  Cerundolo F.  Khachanov K.  Khachanov K.
# 25358  Quarterfinals        3    Alcaraz C.      Fritz T.    Alcaraz C.
# 25359     Semifinals        3  Khachanov K.   Medvedev D.   Medvedev D.
# 25360     Semifinals        3     Sinner J.    Alcaraz C.     Sinner J.
# 25361      The Final        3     Sinner J.   Medvedev D.   Medvedev D.
#
#        Rank_1  Rank_2  Pts_1  Pts_2  Odd_1  Odd_2          score
# 0          28      57   1215    778   1.36   3.00     6-4 6-4
# 1          35      41   1075    927   2.20   1.61  3-6 6-2 1-6
# 2          19      49   1830    845   1.25   3.75     7-5 6-2
# 3         326      36    137   1070   9.00   1.07     4-6 4-6
# 4          43      30    897   1175   1.90   1.80     6-1 6-2
# ...       ...     ...    ...    ...    ...    ...            ...
# 25357      31      16   1320   2505   3.20   1.36     3-6 2-6
# 25358       1      10   7420   2975   1.22   4.33     6-4 6-2
# 25359      16       5   2505   4330   4.50   1.20  6-7 6-3 3-6
# 25360      11       1   2925   7420   3.00   1.40  6-7 6-4 6-2
# 25361      11       5   2925   4330   1.91   1.91     5-7 3-6
#
# [14832 rows x 17 columns]

# %% [markdown]
# What is the lowest ranked player competing in each round of the ATP Tour Hard Surface?

# %%
r_atp = hard.groupby('Round')
# Use a dictionary to specify aggregation functions for each column
agg_dict = {
    'Rank_1': ['max', 'min'],
    'Rank_2': ['max', 'min']
}

# Apply .agg() using the dictionary
atp_agg = r_atp.agg(agg_dict)
#atp_agg.rename(columns={'Rank_1': 'Rank 1'}, inplace=True)
#rename for all other columns

# Display the aggregated DataFrame
atp_agg
# Out:
#               Rank_1     Rank_2
#                  max min    max min
# Round
# 1st Round       2146   1   1690   1
# 2nd Round       1761   1   1045   1
# 3rd Round        832   1    256   1
# 4th Round        144   1    192   1
# Quarterfinals    837   1   1042   1
# Round Robin       11   1     12   1
# Semifinals      1042   1    454   1
# The Final        454   1    167   1

# %%
#Who is this 454 ranked player?
lucky_player = hard[(hard['Round'] == 'The Final') & (hard['Rank_1'] == 454)]
lucky_player
# Out:
#                    Tournament        Date  Series    Court Surface      Round  \
# 12297  Abierto Mexicano Mifel  2017-08-06  ATP250  Outdoor    Hard  The Final
#
#        Best of       Player_1    Player_2      Winner  Rank_1  Rank_2  Pts_1  \
# 12297        3  Kokkinakis T.  Querrey S.  Querrey S.     454      24     85
#
#        Pts_2  Odd_1  Odd_2          score
# 12297   1740   2.75   1.44  3-6 6-3 2-6

# %%
def percen(x):
    return x.count()/atp['Surface'].count()*100
#What percentage of matches are hard, grass and clay from ATP Tour 2013-2023?
atp_example = atp.groupby('Surface').agg({'Rank_1':percen})

atp_example
# Out:
#             Rank_1
# Surface
# Clay     30.415582
# Grass    11.103225
# Hard     58.481192

# %% [markdown]
# ## Reshaping

# %% [markdown]
# ### Pandas Pivot and Pivot Table
# Pandas provides pivot() and pivot_table() functions to reshape data into a summarized table for analysis. Let's explore how to use these functions with some examples.
#
# #### Pivot
# The pivot() function is used to reshape a DataFrame by converting column values into index values.

# %% [markdown]
# **Syntax:**
#
# `df.pivot(index=None, columns=None, values=None)`
#
# **Parameters:**
#
# * index - Column to use as the row index.
# * columns - Column to use as the column index.
# * values - Column to aggregate.
#
# **Returns:**
#
# Pivoted dataframe.

# %%
import pandas as pd

data = {'Brand': ['Toyota','Honda','Toyota','Ford','Honda','Toyota'], 
        'Model': ['Corolla','Civic','Camry','Focus','Accord','Prius'],
        'Year': [2018,2019,2020,2018,2019,2021],
        'Price': [20000,22000,25000,21000,24000,28000],
        'Kilometers':[30000,27000,20000,26000,25000,19000]}

df = pd.DataFrame(data)
df
# Out:
#     Brand    Model  Year  Price  Kilometers
# 0  Toyota  Corolla  2018  20000       30000
# 1   Honda    Civic  2019  22000       27000
# 2  Toyota    Camry  2020  25000       20000
# 3    Ford    Focus  2018  21000       26000
# 4   Honda   Accord  2019  24000       25000
# 5  Toyota    Prius  2021  28000       19000

# %% [markdown]
# Now we can pivot the DataFrame with 'Brand' as the index, 'Model' as the columns, and 'Price' as the values:

# %%
df1 = df.pivot(index='Brand', columns='Model', values='Price')
df1.fillna(0, inplace=True)
df1
# Out:
# Model    Accord    Camry    Civic  Corolla    Focus    Prius
# Brand
# Ford        0.0      0.0      0.0      0.0  21000.0      0.0
# Honda   24000.0      0.0  22000.0      0.0      0.0      0.0
# Toyota      0.0  25000.0      0.0  20000.0      0.0  28000.0

# %% [markdown]
# #### Pivot Table
# The pivot_table() function is similar to pivot() but provides more flexibility in calculating and aggregating data in the reshaped table.

# %% [markdown]
# **Syntax:**
#
# `pivot_table(values=None, index=None, columns=None, aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All')`
#
# **Parameters:**
#
#
# * values - Column to aggregate.
# * index - Column(s) to be index.
# * columns - Column(s) to be columns.
# * aggfunc - Aggregation function like 'mean', 'sum', 'count'. Default is 'mean'.
# * fill_value - Value to replace missing values with.
# * margins - Add all row/column aggregates if True.
# * dropna - Drop missing values. Default is True.
# * margins_name - Name prefix for margin columns.
#
# **Returns:**
#
# Pivoted dataframe.

# %%
data = {'Brand': ['Toyota','Honda','Toyota','Ford','Honda','Toyota', 'Tesla', 'Toyota', 'Honda'], 
        'Model': ['Corolla','Civic','Camry','Focus','Accord','Prius', 'Model 3', 'RAV4', 'CR-V'],
        'Year': [2018,2019,2020,2018,2019,2021, 2020, 2019, 2020],
        'Price': [20000,22000,25000,21000,24000,28000, 50000, 28000, 27000],
        'Kilometers':[30000,27000,20000,26000,25000,19000, 10000, 31000, 22000]}

df = pd.DataFrame(data)
df
# Out:
#     Brand    Model  Year  Price  Kilometers
# 0  Toyota  Corolla  2018  20000       30000
# 1   Honda    Civic  2019  22000       27000
# 2  Toyota    Camry  2020  25000       20000
# 3    Ford    Focus  2018  21000       26000
# 4   Honda   Accord  2019  24000       25000
# 5  Toyota    Prius  2021  28000       19000
# 6   Tesla  Model 3  2020  50000       10000
# 7  Toyota     RAV4  2019  28000       31000
# 8   Honda     CR-V  2020  27000       22000

# %%
df.pivot_table(values='Price', index='Brand', columns='Model', aggfunc='mean')
# Out:
# Model    Accord     CR-V    Camry    Civic  Corolla    Focus  Model 3  \
# Brand
# Ford        NaN      NaN      NaN      NaN      NaN  21000.0      NaN
# Honda   24000.0  27000.0      NaN  22000.0      NaN      NaN      NaN
# Tesla       NaN      NaN      NaN      NaN      NaN      NaN  50000.0
# Toyota      NaN      NaN  25000.0      NaN  20000.0      NaN      NaN
#
# Model     Prius     RAV4
# Brand
# Ford        NaN      NaN
# Honda       NaN      NaN
# Tesla       NaN      NaN
# Toyota  28000.0  28000.0

# %%
#Multiple aggregated values
df.pivot_table(values=['Price', 'Kilometers'], index='Brand', columns='Model',aggfunc=['mean', 'max'])
# Out:
#              mean                                                        \
#        Kilometers
# Model      Accord     CR-V    Camry    Civic  Corolla    Focus  Model 3
# Brand
# Ford          NaN      NaN      NaN      NaN      NaN  26000.0      NaN
# Honda     25000.0  22000.0      NaN  27000.0      NaN      NaN      NaN
# Tesla         NaN      NaN      NaN      NaN      NaN      NaN  10000.0
# Toyota        NaN      NaN  20000.0      NaN  30000.0      NaN      NaN
#
#                                    ...        max                             \
#                             Price  ... Kilometers    Price
# Model     Prius     RAV4   Accord  ...       RAV4   Accord     CR-V    Camry
# Brand                              ...
# Ford        NaN      NaN      NaN  ...        NaN      NaN      NaN      NaN
# Honda       NaN      NaN  24000.0  ...        NaN  24000.0  27000.0      NaN
# Tesla       NaN      NaN      NaN  ...        NaN      NaN      NaN      NaN
# Toyota  19000.0  31000.0      NaN  ...    31000.0      NaN      NaN  25000.0
#
#
#
# Model     Civic  Corolla    Focus  Model 3    Prius     RAV4
# Brand
# Ford        NaN      NaN  21000.0      NaN      NaN      NaN
# Honda   22000.0      NaN      NaN      NaN      NaN      NaN
# Tesla       NaN      NaN      NaN  50000.0      NaN      NaN
# Toyota      NaN  20000.0      NaN      NaN  28000.0  28000.0
#
# [4 rows x 36 columns]

# %%
# Adding new columns
df.pivot_table(values='Price', index='Brand', columns='Model', aggfunc='mean', margins=True)
# Out:
# Model    Accord     CR-V    Camry    Civic  Corolla    Focus  Model 3  \
# Brand
# Ford        NaN      NaN      NaN      NaN      NaN  21000.0      NaN
# Honda   24000.0  27000.0      NaN  22000.0      NaN      NaN      NaN
# Tesla       NaN      NaN      NaN      NaN      NaN      NaN  50000.0
# Toyota      NaN      NaN  25000.0      NaN  20000.0      NaN      NaN
# All     24000.0  27000.0  25000.0  22000.0  20000.0  21000.0  50000.0
#
# Model     Prius     RAV4           All
# Brand
# Ford        NaN      NaN  21000.000000
# Honda       NaN      NaN  24333.333333
# Tesla       NaN      NaN  50000.000000
# Toyota  28000.0  28000.0  25250.000000
# All     28000.0  28000.0  27222.222222

# %% [markdown]
# ### Webscrapping OCU's sports statistics

# %%
# URL of the webpage containing the HTML table(s)
url = 'https://gomightyoaks.com/sports/baseball/stats/2022'

# Read the HTML tables from the webpage
baseball = pd.read_html(url)

# Depending on the webpage structure, there might be multiple tables
# You can access each table using tables[index], where index is the index of the table you want to extract

# For example, to extract the first table
ocu = baseball[6]
ocu
# Out:
#           Date  Loc                    Opponent  W/L  Score    AB    R    H  \
# 0     2/6/2022   at             Johnson (Tenn.)    W  11-10    38   11   11
# 1     2/7/2022   at             Johnson (Tenn.)    W   11-1    35   11   14
# 2     2/7/2022   at             Johnson (Tenn.)    L    5-9    25    5    6
# 3    2/11/2022   vs                      Goshen    L    7-8    31    7   10
# 4    2/11/2022   vs                      Goshen    W   13-2    27   13   10
# 5    2/15/2022  NaN                 Thomas More    W   13-9    34   13   12
# 6    2/20/2022  NaN                 Bethel (IN)    L    2-7    28    2    6
# 7    2/20/2022  NaN                 Bethel (IN)    W    7-6    25    7    9
# 8    2/21/2022  NaN                 Bethel (IN)    L    3-5    28    3    9
# 9    2/21/2022  NaN                 Bethel (IN)    W    5-4    27    5    8
# 10   2/23/2022   at                      Asbury    W    9-2    35    9   10
# 11   2/26/2022  NaN        Grace Christian Univ    W   13-1    28   13   11
# 12   2/26/2022  NaN  Grace Christian University    W   13-4    29   13   13
# 13   2/27/2022  NaN        Grace Christian Univ    W   11-1    27   11   10
# 14   2/27/2022  NaN  Grace Christian University    W   26-0    30   26   15
# 15    3/4/2022  NaN                    WVU Tech    W    4-2    32    4    6
# 16    3/5/2022  NaN                    WVU Tech    W  11-10    42   11   14
# 17    3/5/2022  NaN                    WVU Tech    L    6-7    24    6    7
# 18    3/8/2022   at              Lindsey Wilson    L   7-10    37    7   10
# 19   3/10/2022  NaN                  Point Park    L    0-1    22    0    2
# 20   3/11/2022  NaN                  Point Park    W    8-6    34    8   10
# 21   3/11/2022  NaN                  Point Park    L    4-6    30    4    7
# 22   3/15/2022   at                     Evangel    L    2-3    31    2    6
# 23   3/16/2022   at         Baptist Bible (Mo.)    W   10-8    37   10   10
# 24   3/19/2022   at                  Rio Grande    L    3-7    36    3    9
# 25   3/20/2022   at                  Rio Grande    L   7-12    34    7    7
# 26   3/20/2022   at                  Rio Grande    W   16-3    39   16   17
# 27   3/25/2022   at                   IU Kokomo    L    4-5    34    4    7
# 28   3/25/2022   at                   IU Kokomo    L   0-15    23    0    3
# 29   3/29/2022  NaN                 Bethel (TN)    W    3-0    26    3    7
# 30   3/29/2022  NaN                 Bethel (TN)    W    3-2    19    3    1
# 31    4/1/2022  NaN           Indiana Southeast    L    7-8    35    7    7
# 32    4/1/2022  NaN           Indiana Southeast    L   4-16    24    4    6
# 33    4/2/2022  NaN           Indiana Southeast    W   10-9    43   10   13
# 34   4/10/2022   at                      Midway    L    2-3    33    2    6
# 35   4/10/2022   at                      Midway    W   14-0    35   14   16
# 36   4/12/2022   at            Southern Indiana    W    6-4    33    6    9
# 37   4/19/2022   at                 Bethel (TN)    W    4-2    24    4    4
# 38   4/19/2022   at                 Bethel (TN)    W    1-0    25    1    5
# 39   4/22/2022   at                     Brescia    L    2-4    31    2    5
# 40   4/23/2022   at                     Brescia    W    6-2    32    6    9
# 41   4/23/2022   at                     Brescia    W    7-3    30    7   10
# 42   4/26/2022  NaN   Kentucky State University    L    0-2    25    0    4
# 43   4/26/2022  NaN   Kentucky State University    L    0-2    27    0    7
# 44   4/28/2022  NaN              Ohio Christian    W    3-2    38    3    9
# 45   4/28/2022  NaN              Ohio Christian    W   10-9    30   10   13
# 46   4/29/2022  NaN              Ohio Christian    W    7-6    36    7   12
# 47    5/5/2022   vs                  Point Park    L   0-11    28    0    5
# 48    5/7/2022   vs                  Rio Grande    W    6-1    30    6    8
# 49    5/8/2022   vs                      Midway    L   9-10    38    9    9
# 50  2022-05-10   vs                 Alice Llyod    W   18-4    35   18   17
# 51  2022-05-11  NaN                      Asbury    L    3-4    35    3    6
# 52  2022-05-11   at          Kentucky Christian    W   10-8    40   10   13
# 53  2022-05-12   at                      Asbury    L  10-11    36   10   12
# 54       Total  NaN                         NaN  NaN    NaN  1690  376  482
#
#     RBI   2B  ...  CS  HBP  SH  SF  GDP    K    PO    A   E    AVG
# 0     8    4  ...   0    5   0   0    0    4    27   10   1  0.289
# 1     9    5  ...   0    3   0   0    0    3    21    6   0  0.400
# 2     3    1  ...   0    1   0   1    1    2    18    8   2  0.240
# 3     3    2  ...   0    0   0   0    1    7    21    5   1  0.323
# 4     9    0  ...   0    1   2   1    0    4    21    5   2  0.370
# 5    11    1  ...   1    0   1   0    2    4    27    7   3  0.353
# 6     2    0  ...   0    0   0   0    0   11    21    7   1  0.214
# 7     6    1  ...   0    0   1   1    0    6    21    8   2  0.360
# 8     3    1  ...   0    0   1   0    1    6    21    7   1  0.321
# 9     5    2  ...   2    1   1   1    0    5    24    9   2  0.296
# 10    8    1  ...   0    2   0   1    0    5    27   11   1  0.286
# 11    9    2  ...   0    5   0   0    1    5    21    8   1  0.393
# 12   11    2  ...   0    0   0   0    0    3    18    6   2  0.448
# 13    9    3  ...   0    2   0   0    0    2    21    7   0  0.370
# 14   19    5  ...   0    4   0   1    0    4    15    8   1  0.500
# 15    3    1  ...   0    0   0   0    0    4    27    9   1  0.188
# 16   11    2  ...   0    0   2   2    0   10    33   10   2  0.333
# 17    6    1  ...   0    0   1   1    0    8    18    5   3  0.292
# 18    3    3  ...   0    1   0   0    1    9    24    8   1  0.270
# 19    0    0  ...   0    0   0   0    1    3    21    6   5  0.091
# 20    7    1  ...   0    1   0   0    0    9    27   11   1  0.294
# 21    4    2  ...   1    1   0   0    1    9    27    5   3  0.233
# 22    2    2  ...   0    0   0   0    0    9    24   11   4  0.194
# 23    8    3  ...   0    4   0   0    1    5    27   13   0  0.270
# 24    3    0  ...   0    0   0   0    0    6    24   11   2  0.250
# 25    6    1  ...   1    2   0   2    0    6    24   15   6  0.206
# 26   14    5  ...   0    2   0   2    0   10    21    5   2  0.436
# 27    4    1  ...   0    0   2   0    0    7    24   11   3  0.206
# 28    0    0  ...   0    0   0   0    0    6    18    8   3  0.130
# 29    3    1  ...   0    0   0   0    0    3    21    5   1  0.269
# 30    3    0  ...   0    1   0   1    0    4    22    8   3  0.053
# 31    7    3  ...   1    1   0   0    0    9    27    7   1  0.200
# 32    4    0  ...   0    3   0   1    0    6    21    6   2  0.250
# 33   10    3  ...   0    2   0   0    0   19    33   15   2  0.302
# 34    1    2  ...   0    1   0   0    0   14    24    7   1  0.182
# 35   13    4  ...   1    1   0   0    0    8    21    6   0  0.457
# 36    5    2  ...   0    1   0   0    0    9    27    7   1  0.273
# 37    3    2  ...   1    1   0   1    0    8    21    8   1  0.167
# 38    1    0  ...   1    1   0   0    0    5    21    5   1  0.200
# 39    2    0  ...   0    2   1   0    0   11    24    8   0  0.161
# 40    6    0  ...   2    0   1   0    0    4    27   10   2  0.281
# 41    7    2  ...   0    0   0   2    0    2    21    5   1  0.333
# 42    0    0  ...   0    0   0   0    0    4    21    5   1  0.160
# 43    0    3  ...   1    0   0   0    0   12    21    7   1  0.259
# 44    2    3  ...   0    1   0   1    0    7    33    7   1  0.237
# 45   10    1  ...   0    1   0   0    0    5    21   10   2  0.433
# 46    7    2  ...   1    1   0   2    0   11    27   10   0  0.333
# 47    0    1  ...   0    0   0   0    2    4    22    6   2  0.179
# 48    4    2  ...   0    1   2   0    0    6    27   10   0  0.267
# 49    9    3  ...   0    0   0   1    1    8    24    6   0  0.237
# 50   16    8  ...   0    1   0   0    0    2    21    7   0  0.486
# 51    3    2  ...   0    0   0   0    0    8    27    6   2  0.171
# 52    8    1  ...   1    1   0   0    0    2    27    9   1  0.325
# 53   10    3  ...   1    3   0   0    0    4    24    9   4  0.333
# 54  320  100  ...  15   58  15  22   13  347  1268  429  86    NaN
#
# [55 rows x 25 columns]

# %%
#Create a pivot table that groups by Opponent and provides two columns W or L, and I am interested in know the in average the number of runs against opponents
ocu.pivot_table(values='R', index='Opponent', columns='W/L', aggfunc='mean', margins=True)
# Out:
# W/L                                L          W        All
# Opponent
# Alice Llyod                      NaN  18.000000  18.000000
# Asbury                      6.500000   9.000000   7.333333
# Baptist Bible (Mo.)              NaN  10.000000  10.000000
# Bethel (IN)                 2.500000   6.000000   4.250000
# Bethel (TN)                      NaN   2.750000   2.750000
# Brescia                     2.000000   6.500000   5.000000
# Evangel                     2.000000        NaN   2.000000
# Goshen                      7.000000  13.000000  10.000000
# Grace Christian Univ             NaN  12.000000  12.000000
# Grace Christian University       NaN  19.500000  19.500000
# IU Kokomo                   2.000000        NaN   2.000000
# Indiana Southeast           5.500000  10.000000   7.000000
# Johnson (Tenn.)             5.000000  11.000000   9.000000
# Kentucky Christian               NaN  10.000000  10.000000
# Kentucky State University   0.000000        NaN   0.000000
# Lindsey Wilson              7.000000        NaN   7.000000
# Midway                      5.500000  14.000000   8.333333
# Ohio Christian                   NaN   6.666667   6.666667
# Point Park                  1.333333   8.000000   3.000000
# Rio Grande                  5.000000  11.000000   8.000000
# Southern Indiana                 NaN   6.000000   6.000000
# Thomas More                      NaN  13.000000  13.000000
# WVU Tech                    6.000000   7.500000   7.000000
# All                         3.782609   9.322581   6.962963

# %% [markdown]
# ### Melt
# The melt() function in pandas is used to unpivot or reshape your data from wide to long format. This allows you to reduce the number of columns in your dataframe by "melting" multiple columns into a single column.

# %% [markdown]
# **Syntax**
#
# `df.melt(id_vars=None, value_vars=None, var_name=None, value_name='value', col_level=None)`
#
# **Parameters:**
#
# * id_vars : Column(s) to use as identifier variables.
# * value_vars : Column(s) to unpivot. If not specified, uses all columns that are not set as id_vars.
# * var_name : Name to use for the 'variable' column. Default is 'variable'.
# * value_name : Name to use for the 'value' column. Default is 'value'.
# * col_level : If columns are a MultiIndex then use this level to melt.
#
# **Returns:**
#
# Pivoted DataFrame in long format.

# %%
cars = pd.DataFrame({'Car Model': ['Prius', 'CX-5', 'Tesla Model 3', 'Camry'],
                  'MPG': [50, 25, 30, 28],
                  'Horsepower': [120, 187, 258, 203], 
                  'Weight': [3000, 3500, 4079, 3300]})
cars
# Out:
#        Car Model  MPG  Horsepower  Weight
# 0          Prius   50         120    3000
# 1           CX-5   25         187    3500
# 2  Tesla Model 3   30         258    4079
# 3          Camry   28         203    3300

# %%
melted_df = cars.melt(id_vars='Car Model', 
                    value_vars=['MPG', 'Horsepower', 'Weight'])

melted_df
# Out:
#         Car Model    variable  value
# 0           Prius         MPG     50
# 1            CX-5         MPG     25
# 2   Tesla Model 3         MPG     30
# 3           Camry         MPG     28
# 4           Prius  Horsepower    120
# 5            CX-5  Horsepower    187
# 6   Tesla Model 3  Horsepower    258
# 7           Camry  Horsepower    203
# 8           Prius      Weight   3000
# 9            CX-5      Weight   3500
# 10  Tesla Model 3      Weight   4079
# 11          Camry      Weight   3300

# %%
#Renaming columns
melted_df = cars.melt(id_vars='Car Model', 
                    value_vars=['MPG', 'Horsepower', 'Weight'],
                    var_name='Metric',
                    value_name='Value')

melted_df
# Out:
#         Car Model      Metric  Value
# 0           Prius         MPG     50
# 1            CX-5         MPG     25
# 2   Tesla Model 3         MPG     30
# 3           Camry         MPG     28
# 4           Prius  Horsepower    120
# 5            CX-5  Horsepower    187
# 6   Tesla Model 3  Horsepower    258
# 7           Camry  Horsepower    203
# 8           Prius      Weight   3000
# 9            CX-5      Weight   3500
# 10  Tesla Model 3      Weight   4079
# 11          Camry      Weight   3300

# %%
repivotting = melted_df.pivot(index='Car Model', columns='Metric', values='Value')
repivotting
# Out:
# Metric         Horsepower  MPG  Weight
# Car Model
# CX-5                  187   25    3500
# Camry                 203   28    3300
# Prius                 120   50    3000
# Tesla Model 3         258   30    4079
